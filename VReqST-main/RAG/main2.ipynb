# %%
import getpass
import os
import json

os.environ["OPENAI_API_KEY"] = getpass.getpass()

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain import hub
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

loader = PyPDFLoader("./chess.pdf")
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
text = format_docs(docs)

import tiktoken
model = "gpt-4"
encoding = tiktoken.encoding_for_model(model)

tokens = encoding.encode(text)
token_count = len(tokens)

print(token_count)
# Out:
# 5775

# %%
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")
# Out:
# /home/amogha/.local/lib/python3.10/site-packages/langsmith/client.py:234: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
from glob import glob
with open("scene.json") as scene_file, open("scene-validator.json") as validator_file:
    scene_data = json.load(scene_file)
    validator_data = json.load(validator_file)

def load_examples(folder_path):
    example_files = glob(os.path.join(folder_path, "*.json"))
    examples = {}
    
    for file_path in example_files:
        file_name = os.path.basename(file_path).replace(".json", "")
        with open(file_path, 'r') as f:
            example_data = json.load(f)
            for field, value in example_data.items():
                if field not in examples:
                    examples[field] = []
                examples[field].append({
                    "input": f"{file_name}.",
                    "output": value
                })
    return examples

examples_folder = "./examples"
examples = load_examples(examples_folder)

def generate_question_for_field(field_name, validation_rules, examples):
    typeof = validation_rules.get("typeof", "text")
    query = validation_rules.get("query", f"Please provide the value for {field_name}")
    comment = validation_rules.get("%comment%", "")
    
    question = f"{query} (Expected type: {typeof})?"
    if comment:
        question += f" Note: {comment}"
    
    if typeof == "object":
        question = f"How many {query}? Please provide details for each. {comment}"

    if field_name in examples:
        few_shot_examples = "\n\n".join(
            f"Input: {ex['input']}\nOutput: {ex['output']}"
            for ex in examples[field_name]
        )
        question = f"Examples:\n{few_shot_examples}\n\n{question}"
    
    return question

questions = {
    field: generate_question_for_field(field, rules, examples)
    for field, rules in validator_data.items()
}

# %%
print(questions)
# Out:
# {'_scenename': 'Examples:\nInput: bowling alley.\nOutput: Bowlling Alley\n\nInput: restaurant.\nOutput: Restaurant scene\n\nInput: train.\nOutput: Train scene\n\nPlease provide the value for _scenename (Expected type: string)? Note: Mention your VR Scene name here', '_sid': 'Examples:\nInput: bowling alley.\nOutput: 45189\n\nInput: restaurant.\nOutput: scene_res\n\nInput: train.\nOutput: scene_train\n\nPlease provide the value for _sid (Expected type: string)? Note: A fillable Unique Identifier of the scene', '_slabel': 'Examples:\nInput: bowling alley.\nOutput: This is a interactive game\n\nInput: restaurant.\nOutput: This scene can be used to simulate social interactions that may trigger anxiety or paranoia in individuals with psychosis. Avatars can be used to simulate a difficult conversation with a stranger, or simulate an uncomfortable situation at the restaurant, such as a spill or a loud noise.\n\nInput: train.\nOutput: This scene can help the user get accustomed with moving in crowded places and talking to complete strangers. This involves asking strangers for the train to choose, booking a train ticket, performing money transactions, asking a stranger for the right stop for getting down\n\nPlease provide the value for _slabel (Expected type: string)? Note: A fillable Optional text field for scene description in 200 words', '#pid': 'Please provide the value for #pid (Expected type: string)? Note: Unique identifier for playarea in the VR Scene', '#length_playarea': 'Please provide the value for #length_playarea (Expected type: string)? Note: Length dimension of the playarea and it is mandatory value tag', '#breadth_playarea': 'Please provide the value for #breadth_playarea (Expected type: string)? Note: Breadth dimension of the playarea and it is mandatory value tag', '#height_playarea': 'Please provide the value for #height_playarea (Expected type: string)? Note: Height dimension of the playarea and it is mandatory value tag', '#x_scenecenter': 'Please provide the value for #x_scenecenter (Expected type: number)? Note: x-axis value of scene center of the playarea and it is mandatory value tag', '#y_scenecenter': 'Please provide the value for #y_scenecenter (Expected type: number)? Note: y-axis value of scene center of the playarea and it is mandatory value tag', '#z_scenecenter': 'Please provide the value for #z_scenecenter (Expected type: number)? Note: z-axis value of scene center of the playarea and it is mandatory value tag', 'IsSceneObject': 'Please provide the value for IsSceneObject (Expected type: boolean)? Note: true for yes, false for no. This is to set initial camera in the scene. Additional attributes include IsSceneObject which holds boolean value and trackingorigin holds string value i.e. either floor (physical real-world ground) or +/- height from the physical real-world ground. Example: 5+floor', 'trackingorigin': 'Please provide the value for trackingorigin (Expected type: string)? Note: true for yes, false for no. This is to set initial camera in the scene. Additional attributes include IsSceneObject which holds boolean value and trackingorigin holds string value i.e. either floor (physical real-world ground) or +/- height from the physical real-world ground. Example: 5+floor', '#x_initialcamerapos': 'Please provide the value for #x_initialcamerapos (Expected type: number)? Note: x-axis value of initial camera position of the playarea and it is mandatory value tag', '#y_initialcamerapos': 'Please provide the value for #y_initialcamerapos (Expected type: number)? Note: y-axis value of initial camera position of the playarea and it is mandatory value tag', '#z_initialcamerapos': 'Please provide the value for #z_initialcamerapos (Expected type: number)? Note: z-axis value of initial camera position of the playarea and it is mandatory value tag', '#x_viewport': 'Please provide the value for #x_viewport (Expected type: number)? Note: x-axis value of viewport of the playarea and it is mandatory value tag',  ...

# %%
token_count = 0
for field, question in questions.items():
    tokens = encoding.encode(question)
    token_count += len(tokens)

print(token_count)
# Out:
# 2435

# %%
prompt_text = """
You are tasked with generating the VR requirements for a chess game scene. Based on the given JSON structure, you should fill in the required fields by answering questions related to the environment setup, user interactions, game mechanics, user interface, and immersion enhancements. 

For each question, refer to the provided examples from prior scenes to guide your responses. These examples illustrate expected answer formats and detail levels. Use them to provide comprehensive, specific specifications that will be used to populate the scene configuration accurately.
"""

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

responses = []
for field, question in questions.items():
    print(f"Filling field '{field}'")
    full_prompt = f"{prompt_text}\n\nQuestion: {question}"
    response = rag_chain.invoke(full_prompt)
    print(f"Answer: {response}")
    responses.append(response)
# Out:
# Filling field '_scenename'
# Answer: Chess scene
# Filling field '_sid'
# Answer: scene_chess
# Filling field '_slabel'
# Answer: This scene represents an immersive chess game environment, where players engage in strategic gameplay on a traditional 8x8 chessboard. The board features alternating light and dark squares, with pieces positioned according to standard chess rules, allowing for competitive interaction. Players can experience both solo and multiplayer modes, enhancing social engagement and cognitive challenge in a virtual reality setting.
# Filling field '#pid'
# Answer: The value for #pid should be a unique identifier string that represents the play area in the VR scene. You could use a format such as "chess_playarea_001" to ensure it is distinctive. This string should be consistent with any existing naming conventions in your project.
# Filling field '#length_playarea'
# Answer: The value for #length_playarea should be "8.5 feet". This dimension allows for adequate space around the standard 8x8 chessboard for player movement and interaction in a VR environment.
# Filling field '#breadth_playarea'
# Answer: The value for #breadth_playarea should be "8". This corresponds to the eight columns (files) of the chessboard. The play area is square, with both breadth and length being equal to the number of files.
# Filling field '#height_playarea'
# Answer: The value for #height_playarea should be "1.5 meters" to ensure an optimal viewing and interaction height for players in a VR chess game.
# Filling field '#x_scenecenter'
# Answer: The value for #x_scenecenter should be 0, as the scene center for a chess game on an 8x8 board is typically positioned at the origin of the coordinate system. This central placement allows for equal access to all squares on the board.
# Filling field '#y_scenecenter'
# Answer: The value for #y_scenecenter should be 0, as it represents the y-axis value of the scene center in a standard chess game setup. This places the center of the board at an equal distance from both players, ensuring a balanced play area.
# Filling field '#z_scenecenter'
# Answer: The value for #z_scenecenter should be 0, as the z-axis center of the play area typically represents the midpoint for balanced orientation in 3D environments. This allows for an equal perspective for both players.
# Filling field 'IsSceneObject'
# Answer: The value for IsSceneObject should be true, as the initial camera setup is intended to be part of the scene.
# Filling field 'trackingorigin'
# Answer: The value for trackingorigin should be set to "floor" to establish the initial camera position at the physical real-world ground level.
# Filling field '#x_initialcamerapos'
# Answer: I don't know.
# Filling field '#y_initialcamerapos'
# Answer: I don't know.
# Filling field '#z_initialcamerapos'
# Answer: I don't know.
# Filling field '#x_viewport'
# Answer: The value for #x_viewport should be set to 8, which corresponds to the width of the chessboard in the x-axis, given it consists of 8 squares across.
# Filling field '#y_viewport'
# Answer: The value for #y_viewport is not provided in the retrieved context, so I don't know the answer.
# Filling field '#w_viewport'
# Answer: The value for #w_viewport should be 800, as a chessboard typically requires sufficient space for user interaction and visibility of the 8x8 grid. This width ensures that each square is adequately represented in a VR environment.
# Filling field '#h_viewport'
# Answer: The value for #h_viewport should be 800, which accommodates a standard chess board size in a virtual reality setup, allowing for a clear view of the entire play area.
# Filling field 'near_cp'
# Answer: The value for near_cp should be set to a standard near clipping plane, which is typically around 0.1. This ensures that objects closer than this distance are clipped from the view in a VR environment. Therefore, near_cp should be set to 0.1.
# Filling field 'far_cp'
# Answer: I don't know.
# Filling field '_horizon'
# Answer: False
# Filling field '_dof'
# Answer: 6
# Filling field '_skybox'
# Answer: 3
# Filling field 'type'
# Answer: The value for type should be "single".
# Filling field 'raycast'
# Answer: The value for raycast should be true, as it is necessary for detecting interactions with the chess pieces on the board. This boolean flag indicates whether the raycast function will successfully register hits on the pieces when users interact with the game.
# Filling field 'raydistance'
# Answer: The value for raydistance should be set to 10. This represents the magnitude of the vector from the ray's origin to the impact point in the VR chess game scene.
# Filling field 'raythinkness'
# Answer: The value for raythinkness should be set to 5. This value is within the specified range of 1 to 10 and provides a balanced thickness for ray interactions in the VR chess game scene.
# Filling field 'raycolor'
# Answer: The value for raycolor can be set to "transparent" since there is no specific color mentioned for the ray in the provided context.
# Filling field 'raytype'
# Answer: The value for raytype should be "straightline" as the interactions in a chess game primarily involve direct movements across the board.
# Filling field 'value'
# Answer: The expected value for earth gravity is 10.
# Filling field '_interaction'
# Answer: True
# Filling field '#value'
# Answer: I don't know.
# Filling field '#scenecount'
# Answer: The value for #scenecount is 1, as the chess game scene consists of a single scene with a specific setup.
# Filling field '#sid_order'
# Answer: I don't know.
# Filling field '_audio'
# Answer: True
# Filling field '_timeline'
# Answer: False
# Filling field '_Opttxt1'
# Answer: The chess game scene will feature an 8x8 square board with alternating light and dark squares, typically in colors like white and brown or white and green. The pieces will be arranged in the standard setup with White's rook, knight, bishop, queen, king, bishop, knight, and rook on the first rank, and eight pawns on the second rank, while Black's pieces mirror White's. This configuration ensures an authentic chess experience, aligning with traditional gameplay rules.
# Filling field '@context_mock'
# Answer: _blank
# Filling field 'usertype'
# Answer: [{'type': 'single', 'uplayarea': {'#length': 10, '#breadth': 10, '#height': 5}, 'initialupos': {'#x': 0, '#y': 0, '#z': 0}, 'uplayareacenter': {'#x': 0, '#y': 0, '#z': 0}}]
# Filling field '#length_uplayarea'
# Answer: I don't know.
# Filling field '#breadth_uplayarea'
# Answer: The value for #breadth_uplayarea is 8. This corresponds to the 8 squares across one side of the chessboard, which is a square play area. Each square typically represents a standard unit of measurement in the game environment.
# Filling field '#height_uplayarea'
# Answer: I don't know.
# Filling field '#x_initialupos'
# Answer: The value for #x_initialupos would typically be set at 0, as this represents the starting position along the x-axis for the user in the play area. This assumes the user is centered at the origin point of the board.
# Filling field '#y_initialupos'
# Answer: I don't know.
# Filling field '#z_initialupos'
# Answer: I don't know.
# Filling field '#x_uplayareacenter'
# Answer: The value for #x_uplayareacenter should be 0. This represents the initial position of the user in the play area along the x-axis. This center point is typically set at the origin of the coordinate system used for the VR environment.
# Filling field '#y_uplayareacenter'
# Answer: The value for #y_uplayareacenter is not provided in the context. Therefore, I don't know the answer.
# Filling field '#z_uplayareacenter'
# Answer: I don't know.

# %%
prompt_text = """
You are tasked with generating the VR requirements for a chess game scene. Based on the given JSON structure, you should fill in the required fields by answering questions related to the environment setup, user interactions, game mechanics, user interface, and immersion enhancements. 

For each question, refer to the provided examples from prior scenes to guide your responses. These examples illustrate expected answer formats and answer types. Use them to provide specific answers that are clear and concise, without unnecessary details. Your responses should be succinct and focus on the essential information needed to populate the scene configuration accurately.
"""

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

responses = []
for field, question in questions.items():
    print(f"Filling field '{field}'")
    full_prompt = f"{prompt_text}\n\nQuestion: {question}"
    response = rag_chain.invoke(full_prompt)
    print(f"Answer: {response}")
    responses.append(response)
# Out:
# Filling field '_scenename'
# Answer: Chess scene
# Filling field '_sid'
# Answer: scene_chess
# Filling field '_slabel'
# Answer: This scene represents a virtual reality chess game played on a traditional 8x8 board with alternating light and dark squares. Players can interact by moving pieces according to standard chess rules, while the immersive environment enhances strategic thinking and concentration. The setup includes visual aids for piece placement and timers for competitive play, simulating a real-world chess experience.
# Filling field '#pid'
# Answer: I don't know.
# Filling field '#length_playarea'
# Answer: The value for #length_playarea is "8".
# Filling field '#breadth_playarea'
# Answer: The value for #breadth_playarea is "8".
# Filling field '#height_playarea'
# Answer: The value for #height_playarea should be "1.5 meters". This height allows for an immersive user experience while playing chess in a virtual reality environment. It is important to ensure that players can comfortably engage with the game pieces and board.
# Filling field '#x_scenecenter'
# Answer: The value for #x_scenecenter is 0. This represents the x-axis value of the scene center for the chess game play area.
# Filling field '#y_scenecenter'
# Answer: The value for #y_scenecenter should be 0. This represents the center of the play area on the y-axis, assuming a standard coordinate system where the center is positioned at the origin.
# Filling field '#z_scenecenter'
# Answer: The value for #z_scenecenter is 0.
# Filling field 'IsSceneObject'
# Answer: true
# Filling field 'trackingorigin'
# Answer: The value for trackingorigin should be "floor". This setting establishes the initial camera position at the physical real-world ground level.
# Filling field '#x_initialcamerapos'
# Answer: I don't know.
# Filling field '#y_initialcamerapos'
# Answer: I don't know.
# Filling field '#z_initialcamerapos'
# Answer: I don't know.
# Filling field '#x_viewport'
# Answer: The value for #x_viewport is 8. This corresponds to the eight columns of the chessboard, as the game is played on an 8×8 grid.
# Filling field '#y_viewport'
# Answer: I don't know.
# Filling field '#w_viewport'
# Answer: The value for #w_viewport should be 800, as the chessboard is typically square and consists of 8 rows and 8 columns. Each square can be represented as 100 units in width, resulting in a total width of 800 units for the playable area.
# Filling field '#h_viewport'
# Answer: I don't know.
# Filling field 'near_cp'
# Answer: The value for near_cp is 0.1.
# Filling field 'far_cp'
# Answer: I don't know.
# Filling field '_horizon'
# Answer: False
# Filling field '_dof'
# Answer: 6
# Filling field '_skybox'
# Answer: I don't know.
# Filling field 'type'
# Answer: The value for type is "single".
# Filling field 'raycast'
# Answer: True
# Filling field 'raydistance'
# Answer: The value for raydistance is 10.
# Filling field 'raythinkness'
# Answer: I don't know.
# Filling field 'raycolor'
# Answer: The value for raycolor should be "transparent" for no color.
# Filling field 'raytype'
# Answer: The value for raytype should be "straightline" as the chess pieces move in straight lines along ranks and files on the board.
# Filling field 'value'
# Answer: The value for earth gravity is 10.
# Filling field '_interaction'
# Answer: True
# Filling field '#value'
# Answer: False. There is no indication of a scene within a scene in the provided context. The focus is solely on the chess game and its elements.
# Filling field '#scenecount'
# Answer: The value for #scenecount is 1, as there is only one main scene for the chess game setup.
# Filling field '#sid_order'
# Answer: I don't know.
# Filling field '_audio'
# Answer: True
# Filling field '_timeline'
# Answer: False
# Filling field '_Opttxt1'
# Answer: The value for _Opttxt1 could be: "Use light and dark squares for the chessboard, with the white queen starting on a light square."
# Filling field '@context_mock'
# Answer: _blank
# Filling field 'usertype'
# Answer: [{'type': 'single', 'uplayarea': {'#length': 10, '#breadth': 10, '#height': 5}, 'initialupos': {'#x': -5, '#y': 0, '#z': -5}, 'uplayareacenter': {'#x': -5, '#y': 2.5, '#z': -5}}]
# Filling field '#length_uplayarea'
# Answer: The length of the user play area for a chess game scene should be 1.8 meters. This accommodates the standard chessboard dimensions and allows for player movement around the board.
# Filling field '#breadth_uplayarea'
# Answer: The breadth of the user play area for a chess game scene should be set to 8, as the chessboard consists of 8 columns. This configuration allows for the complete setup of the game pieces across the board. Thus, the value for #breadth_uplayarea is 8.
# Filling field '#height_uplayarea'
# Answer: I don't know.
# Filling field '#x_initialupos'
# Answer: The value for #x_initialupos should be set to 0, as this represents the starting position on the x-axis of the user's play area.
# Filling field '#y_initialupos'
# Answer: I don't know.
# Filling field '#z_initialupos'
# Answer: I don't know.
# Filling field '#x_uplayareacenter'
# Answer: I don't know.
# Filling field '#y_uplayareacenter'
# Answer: I don't know.
# Filling field '#z_uplayareacenter'
# Answer: I don't know.

# %%
print(rag_chain.invoke('Tell me about chess'))
# Out:
# Chess is a two-player board game played on an 8×8 grid, involving strategic moves of sixteen pieces per player, including a king and queen. It has roots in the seventh-century Indian game chaturanga and evolved through Persia to Europe, with modern rules established by the end of the 15th century. Today, chess is governed internationally by FIDE and is one of the most popular games worldwide, with a rich body of theory and competitive history.
